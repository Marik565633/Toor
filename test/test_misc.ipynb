# %%
import toor_distance
# Out:
# Running cells with '.venv (Python 3.12.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/karamn3/Workspace/TOOR/toor_distance/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
toor_distance.image_processor.load_image()
